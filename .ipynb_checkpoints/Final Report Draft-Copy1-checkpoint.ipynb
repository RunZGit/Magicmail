# %% [markdown]
# # Using Tensorflow Word2Vec model

# %%
from gensim.models import Word2Vec
import numpy as np
from sklearn.manifold import TSNE
import pandas as pd
from bokeh.charts import Scatter, show, output_file
from bokeh.models import LabelSet, ColumnDataSource
from bokeh.io import output_notebook,vplot
from bs4 import BeautifulSoup
import re
from nltk.corpus import stopwords
from sklearn import cluster
import pylab as pl
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="120c04c0-acd1-4b2a-aba6-53901ab42bf4">Loading BokehJS ...</span>
#     </div>

# %%
model = Word2Vec.load("./data/300features_40minwords_10context_AnnouncementTitle")

# %%
#lower the dimention of each word vector
tsne=TSNE(random_state=0)
np.set_printoptions(suppress=True)
vec = np.empty((0,100), float)
dic= list(model.vocab.keys())
for i in dic:
    vec = np.vstack((vec, model[i]))
low_dim = tsne.fit_transform(vec)

# %%
## create word graph
df = pd.DataFrame(low_dim, columns=['x','y'])
df['vocab'] = dic
source = ColumnDataSource(data=dict(x=df['x'],
                                    y=df['y'],
                                    vocab=dic))
p = Scatter(df, x='x', y='y', title = "vocab in hypterdimention")
labels = LabelSet(x='x', y='y', text='vocab', level='glyph',
              x_offset=5, y_offset=5, source=source, render_mode='canvas')
p.add_layout(labels)
# output_file("word2vec.html", title="word2vec")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="82b38a85-097c-4548-9f25-7907989f7d90"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %% [markdown]
# # Continues Bag of Words
# ## This function will convert a paragrah to array of words

# %%
def review_to_wordlist( review, remove_stopwords=False ):
    # Function to convert a document to a sequence of words,
    # optionally removing stop words.  Returns a list of words.
    #
    # 1. Remove HTML
    review_text = BeautifulSoup(review).get_text()
    #  
    # 2. Remove non-letters
    review_text = re.sub("[^a-zA-Z]"," ", review_text)
    #
    # 3. Convert words to lower case and split them
    words = review_text.lower().split()
    #
    # 4. Optionally remove stop words (false by default)
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    #
    # 5. Return a list of words
    return(words)

# %% [markdown]
# ## In this step, we tokenize each email body and it's title to an array

# %%
data = pd.read_csv('data/announcements.csv')
features = 100
emails = [None] * data["Body"].shape[0]  # Initialize an empty list of sentences
i = 0
for review in data["Body"]:
    emails[i] = review_to_wordlist(str(review))
    i = i+1

# %% [markdown]
# ## As you can see, we have total of 4167 emails.

# %%
size = len(emails)
print(size)
# Out:
# 4167

# %% [markdown]
# ## We apply cbow in this step. We sum vector value for each word in the email and then average them out to get the vector result of the entire email

# %%
cbow = [None] * data["Body"].shape[0]
i = 0
for email in emails:
    base = [0] * features
    wordSkipped = 0
    for word in email:
        if model.vocab.get(word) is None :
            wordSkipped = wordSkipped+1
            continue
        base = base + model[word]
    cbow[i] = np.array(base) / (len(email) - wordSkipped)
    i = i + 1

# %% [markdown]
# ## This creates a dataframe of 4167 by 100

# %%
cbow = pd.DataFrame(cbow)
cbow.head(10)
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.081044  0.120048 -0.214332  0.023244 -0.194121 -0.135236 -0.124679
# 1  0.083001  0.120911 -0.213671  0.022072 -0.193722 -0.133595 -0.124528
# 2  0.082162  0.119396 -0.213789  0.022896 -0.195183 -0.135445 -0.124993
# 3  0.081430  0.120568 -0.214062  0.022564 -0.194516 -0.135638 -0.123869
# 4  0.082906  0.120533 -0.214117  0.022283 -0.194769 -0.134524 -0.124535
# 5  0.083573  0.119584 -0.212844  0.026070 -0.194044 -0.132119 -0.124431
# 6  0.082129  0.119903 -0.213281  0.021966 -0.195038 -0.135154 -0.124504
# 7  0.081716  0.119168 -0.213707  0.022508 -0.194497 -0.134330 -0.124553
# 8  0.082718  0.119846 -0.214099  0.023783 -0.194817 -0.133712 -0.124341
# 9  0.081896  0.119258 -0.213478  0.021860 -0.195447 -0.135373 -0.125287
#
#          7         8         9     ...           90        91        92  \
# 0 -0.006984  0.012508 -0.018914    ...     0.332130 -0.162919 -0.016504
# ...

# %%
cbow.to_csv("./data/100_features.csv",index = False)

# %% [markdown]
# # Using Tensorflow Word2Vec model

# %%
df = pd.read_csv('./data/email.csv', header=None)
df.head(3)
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.037764  0.014336  0.000178 -0.037297 -0.031119  0.026128 -0.070287
# 1  0.046096  0.032011 -0.025486  0.009135 -0.045694  0.019960 -0.088211
# 2  0.042579  0.028244 -0.047193 -0.025968 -0.006204  0.044185 -0.035565
#
#         7         8         9      ...          118       119       120  \
# 0  0.003502 -0.059951  0.112171    ...    -0.035336  0.022702 -0.014517
# 1 -0.000344 -0.060330  0.105208    ...    -0.000726  0.008629 -0.015821
# 2 -0.013477 -0.085571  0.107871    ...    -0.010689  0.015235 -0.012684
#
#         121       122       123       124       125       126       127
# 0  0.114289 -0.072962 -0.022144  0.013885 -0.030889  0.032176 -0.079394
# 1  0.075698 -0.095679 -0.044916  0.032496  0.010954  0.020992 -0.074257
# 2  0.110166 -0.070666 -0.017062  0.009641 -0.010771  0.008265 -0.071480
#
# [3 rows x 128 columns]

# %% [markdown]
# ## Below shows the dimention reduced graph of the 4167 emails. It seems that the emails are seperated into 9 clusters

# %%
k_means = cluster.KMeans(n_clusters=9, random_state=0)
k_means.fit(df)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=9, n_init=10,
#     n_jobs=1, precompute_distances='auto', random_state=0, tol=0.0001,
#     verbose=0)

# %%
model = TSNE(n_components=2, random_state=0)
np.set_printoptions(suppress=True)
x = model.fit_transform(df)

# %%
pl.scatter(x[:, 0], x[:, 1]) 
pl.show()

# %% [markdown]
# ## After creating 9 clusters, we label each email with the corresponding cluster

# %%
np.reshape(df.ix[0][0:128], [1,-1]).shape
# Out:
# (1, 128)

# %%
df2 = pd.read_csv('./data/testemailvector.csv', header = None)
df2.shape
# Out:
# (7313, 128)

# %%
df_testdata = pd.read_csv('./data/test_try1.csv')

# %%
titles = df_testdata.icol(1)
body = df_testdata.icol(2)
# Out:
# /opt/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: icol(i) is deprecated. Please use .iloc[:,i]
#   if __name__ == '__main__':
# /opt/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:2: FutureWarning: icol(i) is deprecated. Please use .iloc[:,i]
#   from ipykernel import kernelapp as app

# %%
df2['title'] = titles
df2['body'] = body
df2=df2.dropna()

# %%
k_means.predict(df2.ix[103,0:128])
# Out:
# /opt/anaconda3/lib/python3.5/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /opt/anaconda3/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64.
#   warnings.warn(msg, DataConversionWarning)
# array([6], dtype=int32)

# %%
pred = k_means.predict(df2.ix[:,0:128])

# %%
pred = pd.DataFrame(pred)
title = ['General Sales', 'Loft sales', 'Book sales', 'CSS code', 'Lost and found','Need a ride','Intramual','Lost and found','Looking to buy' ]

# %%
cat = []
for i in range(pred.shape[0]):
    cat.append(title[pred.ix[i].values[0]])

# %%
cat[0]
# Out:
# 'Intramual'

# %%
cat
# Out:
# ['Intramual',
#  'Intramual',
#  'General Sales',
#  'Intramual',
#  'Intramual',
#  'General Sales',
#  'Intramual',
#  'Intramual',
#  'Intramual',
#  'General Sales',
#  'General Sales',
#  'Intramual',
#  'Intramual',
#  'Intramual',
#  'Intramual',
#  'General Sales',
#  'Intramual',
#  'General Sales',
#  'Intramual',
#  'General Sales',
#  'Intramual',
#  'Intramual',
#  'General Sales',
#  'General Sales',
#  'Intramual',
#  'Intramual',
#  'Intramual',
#  'General Sales',
#  'Intramual',
#  'Intramual',
#  'Intramual',
#  'Intramual',
#  'Intramual',
#  'Intramual',
#  'Intramual',
#  'Intramual',
#  'General Sales',
#  'Intramual',
#  'Intramual',
#  'Intramual',
#  'Intramual',
#  'Intramual',
#  'Intramual',
#  'Intramual',
#  'Intramual',
#  'Intramual',
#  'Intramual',
#  'General Sales',
#  'General Sales',
#  'Intramual',
#  'General Sales',
#  'General Sales',
#  'Intramual',
#  'General Sales',
#  'General Sales',
#  'Intramual',
#  'Intramual',
#  'General Sales',
# ...

# %%
final = pd.DataFrame(cat)

# %%
final.columns = ['Category']

# %%
final['Title'] = titles
final['Body'] = body

# %%
final.head(1000)
# Out:
#           Category                                              Title  \
# 0        Intramual                                       Lost T-Shirt
# 1        Intramual                                    LOST POWER CORD
# 2    General Sales  SURVEY OH MY GOSH IT"S A SURVEY ABOUT NAPKIN D...
# 3        Intramual                         Physics Textbook for sale.
# 4        Intramual                                  Computer for Sale
# 5    General Sales                        PARKOUR! beginners welcome!
# 6        Intramual           ELECTRICAL SYSTEMS BOOK STILL FOR SALE.
# 7        Intramual                                       Five Dollars
# 8        Intramual                                      Desk for Sale
# 9    General Sales            Child Care Openings from Local Provider
# 10   General Sales                     Special Olympics-we need YOU!!
# 11       Intramual                     Special Olympics-we need YOU!!
# ...

# %%
final.Category.unique()
# Out:
# array(['Intramual', 'General Sales', 'Book sales', 'Lost and found',
#        'Loft sales'], dtype=object)

# %%
bok = final['Category'] == "Book sales"

# %%
bok
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Category, dtype: bool

# %%
cluster = np.zeros([df.shape[0],1])
for i in range(df.shape[0]) :
    row = np.reshape(df.ix[i][0:128], [1,-1])
    cluster[i] = k_means.predict(row)
df['cluster'] = cluster
df2 = pd.DataFrame(x)
df2['cluster'] = cluster
df2.columns = ['X', 'Y', 'cluster']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-f5ef1404e216> in <module>()
#       2 for i in range(df.shape[0]) :
#       3     row = np.reshape(df.ix[i][0:128], [1,-1])
# ----> 4     cluster[i] = k_means.predict(row)
#       5 df['cluster'] = cluster
#       6 df2 = pd.DataFrame(x)
#
# /opt/anaconda3/lib/python3.5/site-packages/sklearn/cluster/k_means_.py in predict(self, X)
#     887         check_is_fitted(self, 'cluster_centers_')
#     888
# --> 889         X = self._check_test_data(X)
#     890         x_squared_norms = row_norms(X, squared=True)
#     891         return _labels_inertia(X, x_squared_norms, self.cluster_centers_)[0]
#
# /opt/anaconda3/lib/python3.5/site-packages/sklearn/cluster/k_means_.py in _check_test_data(self, X)
#     792     def _check_test_data(self, X):
# ...

# %%
df2.to_csv('./data/clustered_emails.csv')

# %%
fig = Scatter(df2,x='X',y='Y',
              color='cluster',
              legend='top_left',
              title='KNN Classifier')
show(fig)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="fbb1ae39-28d6-495f-aa04-3c31ac21997a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
# This function can find the top N common words of every cluster.
def topic(srcaddr,indaddr,topN = 10, N = 9):
    # Import packages
    import pandas as pd
    from nltk.corpus import stopwords
    from nltk.tokenize import RegexpTokenizer
    
    # Load the original csv file and the vectorized csv file
    src = pd.read_csv(srcaddr)
    ind = pd.read_csv(indaddr)
    
    # Create an 2D array to store the words of the original csv file according to the cluster number of vectorized csv file
    ar = []
    for i in range(N):
        ar.append([])
    
    # Initialize the punctuation eliminator
    tokenizer = RegexpTokenizer(r'\w+')
    # Create a list of irrelevant words
    irrelevant_lists = ['rose','Rose','I','edu','hulman','Hulman','www','com','http','The','1','2','3','4','5','6','7','8','9','0','If','It','it','if']
    # Loop through all rows
    for i in range(src.shape[0]):
        # Add the title and the body in the same row to a string
        index = int(ind.cluster[i])
        string = str(src.Title[i])+" "+str(src.Body[i])
        # Get rid of the punctuation, stopwords and the irrelevant words
        a = tokenizer.tokenize(string)
        filtered_word = [word for word in a if word not in stopwords.words('english')]
        for word in filtered_word:
            if(word not in irrelevant_lists):
                # Append the word list to ar of index which we get from cluster number of vectorized csv
                ar[index].append(word)
    
    # Create an empty array to store top N words of every cluster
    top10 = []
    # Loop through number of clusters.
    for k in range(N):
        # Create an empty map
        maps={}
        # Store the number of a word as value and the word as key to the map
        for word in ar[k]:
            maps[word]=0
        for word in ar[k]:
            maps[word] = maps[word]+1
        # Create an empty array to store top N words of a cluster
        temp = []
        # Loop through to find the top N words of a cluster
        for h in range(topN):
            mapscount = 0
            mapskey = ""
            for key in maps:
                if(maps[key]>mapscount):
                    mapskey = key
                    mapscount = maps[key]
            maps[mapskey]=0
            temp.append(mapskey)
        # Store the temp array to top10 array
        top10.append(temp)
    # return top10 2Darray
    return top10

# %%
result = topic('./data/announcements.csv','./data/clustered_emails.csv')
i = 0
for words in result:
    print("Cluster " +str(i)+": ")
    print(words)
    i = i+1
# Out:
# Cluster 0:
# ['Selling', 'selling', 'sale', 'interested', 'condition', 'asking', 'new', 'email', 'used', 'Sale']
# Cluster 1:
# ['interested', 'room', 'looking', 'email', 'loft', 'would', 'year', 'Percopo', 'We', 'Thanks']
# Cluster 2:
# ['book', 'Selling', 'selling', 'interested', 'books', 'Book', 'edition', 'email', 'used', 'Books']
# Cluster 3:
# ['font', '0in', 'serif', 'family', 'sans', 'span', 'color', 'MsoNormal', 'Calibri', 'margin']
# Cluster 4:
# ['Lost', 'please', 'lost', 'found', 'email', 'black', 'Thanks', 'Thank', 'contact', 'know']
# Cluster 5:
# ['ride', 'Indy', 'gas', 'pay', 'Ride', 'airport', 'need', 'back', 'flight', 'Airport']
# Cluster 6:
# ['Please', 'SimplyWell', 'please', 'IM', 'register', '00', 'points', '2014', 'Wednesday', 'Intramural']
# Cluster 7:
# ['found', 'claim', 'A', 'Found', 'describe', 'phone', 'Please', 'cell', 'Moench', 'please']
# Cluster 8:
# ['interested', 'A', '10', 'please', 'contact', 'email', 'Selling', 'one', '30', 'new']
